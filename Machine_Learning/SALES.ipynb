# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivang2003/Machine-Learning-Problems/blob/main/SALES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import io

# %% [markdown]
# reading csv file of video games and
# displaying dataset

# %%
data=pd.read_csv('videogames.csv')
print(data)
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %% [markdown]
# data values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# checking null values

# %%
data[data.Developer.isnull()]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# 5          Nintendo     23.20      2.26      4.22         0.58         30.26
# 9          Nintendo     26.93      0.63      0.28         0.47         28.31
# 10         Nintendo      9.05     10.95      1.93         2.74         24.67
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# 5               NaN           NaN         NaN         NaN       NaN    NaN
# 9               NaN           NaN         NaN         NaN       NaN    NaN
# 10              NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [6623 rows x 16 columns]

# %%
data[data.Genre.isnull()]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 659        0.53      0.00         0.08          2.39           NaN
# 14246      0.00      0.03         0.00          0.03           NaN
#
#        Critic_Count  User_Score  User_Count Developer Rating
# 659             NaN         NaN         NaN       NaN    NaN
# 14246           NaN         NaN         NaN       NaN    NaN

# %%
data[data.Publisher.isnull()]
# Out:
#                                                     Name Platform  \
# 475                           wwe Smackdown vs. Raw 2006      PS2
# 1301                                      Triple Play 99       PS
# 1667        Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2212                                  Bentley's Hackpack      GBA
# 3148   Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3159   SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3755   SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4127                                  Sonic the Hedgehog      PS3
# 4508   The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4615   The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5294       Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5633   Cartoon Network Collection: Game Boy Advance V...      GBA
# 6256   The Legend of Zelda: The Minish Cap(weekly JP ...      GBA
# 6415            Sonic X: Game Boy Advance Video Volume 1      GBA
# 6532   Dora the Explorer: Game Boy Advance Video Volu...      GBA
# 6626   Cartoon Network Collection: Game Boy Advance V...      GBA
# 6831      All Grown Up!: Game Boy Advance Video Volume 1      GBA
# 7189   Nicktoons Collection: Game Boy Advance Video V...      GBA
# 7333                      Yu Yu Hakusho: Dark Tournament      PS2
# 7477   SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 7930                    Thomas the Tank Engine & Friends      GBA
# 8317     Dragon Ball GT: Game Boy Advance Video Volume 1      GBA
# 8328   Codename: Kids Next Door: Game Boy Advance Vid...      GBA
# 8358   Teenage Mutant Ninja Turtles: Game Boy Advance...      GBA
# 8494                                        Stronghold 3       PC
# 8754   Cartoon Network Collection: Game Boy Advance V...      GBA
# 8837   Pokémon: Johto Photo Finish: Game Boy Advance ...      GBA
# 8883   Strawberry Shortcake: Game Boy Advance Video V...      GBA
# 9511                              Farming Simulator 2011       PC
# 9739   Super Robot Wars OG Saga: Masou Kishin II - Re...      PSP
# 10378                   Disney Channel Collection Vol. 1      GBA
# 10487             Atsumare! Power Pro Kun no DS Koushien       DS
# 11093                       Action Man-Operation Extreme       PS
# 11546  Cartoon Network Collection: Game Boy Advance V...      GBA
# 12525                               Chou Soujuu Mecha MG       DS
# 12569       Prinny: Can I Really Be The Hero? (US sales)      PSP
# 13318                     Monster Hunter Frontier Online      PS3
# 13712                          B.L.U.E.: Legend of Water       PS
# 14128                                       Housekeeping       DS
# 14352                                Bikkuriman Daijiten       DS
# 14687                                     World of Tanks     X360
# 14772                                 UK Truck Simulator       PC
# 15024  Umineko no Naku Koro ni San: Shinjitsu to Gens...      PS3
# 15340                                       Mario Tennis      3DS
# 15417  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 15442                   Demolition Company: Gold Edition       PC
# 15680  Moshi, Kono Sekai ni Kami-sama ga Iru to suru ...      PSV
# 16019                                       Dream Dancer       DS
# 16280                    Homeworld Remastered Collection       PC
# 16296             AKB1/48: Idol to Guam de Koishitara...     X360
# 16306  Super Robot Monkey Team: Game Boy Advance Vide...      GBA
# 16332                        Brothers in Arms: Furious 4     X360
# 16339                                  Dance with Devils      PSV
# 16662                             Driving Simulator 2011       PC
#
#        Year_of_Release         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 475                NaN      Fighting       NaN      1.57      1.02      0.00
# 1301               NaN        Sports       NaN      0.81      0.55      0.00
# 1667            2007.0          Misc       NaN      0.87      0.32      0.00
# 2212            2005.0          Misc       NaN      0.67      0.25      0.00
# 3148            2004.0          Misc       NaN      0.46      0.17      0.00
# 3159            2004.0          Misc       NaN      0.46      0.17      0.00
# 3755            2004.0          Misc       NaN      0.38      0.14      0.00
# 4127               NaN      Platform       NaN      0.00      0.48      0.00
# 4508            2004.0          Misc       NaN      0.31      0.11      0.00
# 4615            2004.0          Misc       NaN      0.30      0.11      0.00
# 5294               NaN        Action       NaN      0.15      0.05      0.14
# 5633            2005.0          Misc       NaN      0.23      0.08      0.00
# 6256               NaN        Action       NaN      0.00      0.00      0.27
# 6415            2004.0          Misc       NaN      0.19      0.07      0.00
# 6532            2004.0          Misc       NaN      0.18      0.07      0.00
# 6626            2004.0          Misc       NaN      0.18      0.07      0.00
# 6831            2004.0          Misc       NaN      0.17      0.06      0.00
# 7189            2004.0          Misc       NaN      0.16      0.06      0.00
# 7333               NaN      Fighting       NaN      0.10      0.08      0.00
# 7477            2004.0          Misc       NaN      0.15      0.05      0.00
# 7930            2004.0     Adventure       NaN      0.13      0.05      0.00
# 8317            2004.0          Misc       NaN      0.12      0.05      0.00
# 8328            2004.0          Misc       NaN      0.12      0.05      0.00
# 8358            2004.0          Misc       NaN      0.12      0.04      0.00
# 8494            2011.0      Strategy       NaN      0.06      0.10      0.00
# 8754            2005.0          Misc       NaN      0.11      0.04      0.00
# 8837            2004.0          Misc       NaN      0.11      0.04      0.00
# 8883            2004.0          Misc       NaN      0.11      0.04      0.00
# 9511            2010.0    Simulation       NaN      0.00      0.13      0.00
# 9739               NaN      Strategy       NaN      0.00      0.00      0.12
# 10378           2004.0          Misc       NaN      0.08      0.03      0.00
# 10487              NaN        Sports       NaN      0.00      0.00      0.10
# 11093              NaN        Action       NaN      0.05      0.03      0.00
# 11546           2004.0          Misc       NaN      0.06      0.02      0.00
# 12525              NaN    Simulation       NaN      0.00      0.00      0.06
# 12569              NaN        Action       NaN      0.06      0.00      0.00
# 13318              NaN  Role-Playing       NaN      0.00      0.00      0.05
# 13712              NaN     Adventure       NaN      0.00      0.00      0.04
# 14128              NaN        Action       NaN      0.00      0.00      0.04
# 14352              NaN          Misc       NaN      0.00      0.00      0.03
# 14687              NaN       Shooter       NaN      0.00      0.03      0.00
# 14772           2010.0    Simulation       NaN      0.00      0.03      0.00
# 15024              NaN     Adventure       NaN      0.00      0.00      0.02
# 15340              NaN        Sports       NaN      0.00      0.00      0.02
# 15417           2005.0          Misc       NaN      0.01      0.01      0.00
# 15442           2011.0    Simulation       NaN      0.00      0.02      0.00
# 15680           2016.0     Adventure       NaN      0.00      0.00      0.02
# 16019              NaN          Misc       NaN      0.01      0.00      0.00
# 16280              NaN      Strategy       NaN      0.00      0.01      0.00
# 16296              NaN          Misc       NaN      0.00      0.00      0.01
# 16306           2005.0          Misc       NaN      0.01      0.00      0.00
# 16332              NaN       Shooter       NaN      0.01      0.00      0.00
# 16339           2016.0        Action       NaN      0.00      0.00      0.01
# 16662           2011.0        Racing       NaN      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# 475           0.41          3.00           NaN           NaN         NaN
# 1301          0.10          1.46           NaN           NaN         NaN
# 1667          0.02          1.21           NaN           NaN         NaN
# 2212          0.02          0.93           NaN           NaN         NaN
# 3148          0.01          0.64           NaN           NaN         NaN
# 3159          0.01          0.64           NaN           NaN         NaN
# 3755          0.01          0.53           NaN           NaN         NaN
# 4127          0.00          0.48          43.0          17.0         4.1
# 4508          0.01          0.43           NaN           NaN         NaN
# 4615          0.01          0.42           NaN           NaN         NaN
# 5294          0.01          0.35           NaN           NaN         NaN
# 5633          0.01          0.32           NaN           NaN         NaN
# 6256          0.01          0.27           NaN           NaN         NaN
# 6415          0.00          0.27           NaN           NaN         NaN
# 6532          0.00          0.26           NaN           NaN         NaN
# 6626          0.00          0.25           NaN           NaN         NaN
# 6831          0.00          0.24           NaN           NaN         NaN
# 7189          0.00          0.22           NaN           NaN         NaN
# 7333          0.03          0.21          56.0          15.0         8.5
# 7477          0.00          0.21           NaN           NaN         NaN
# 7930          0.00          0.19           NaN           NaN         NaN
# 8317          0.00          0.17           NaN           NaN         NaN
# 8328          0.00          0.17           NaN           NaN         NaN
# 8358          0.00          0.17           NaN           NaN         NaN
# 8494          0.00          0.16          47.0          29.0         3.0
# 8754          0.00          0.15           NaN           NaN         NaN
# 8837          0.00          0.15           NaN           NaN         NaN
# 8883          0.00          0.15           NaN           NaN         NaN
# 9511          0.00          0.13           NaN           NaN         7.0
# 9739          0.00          0.12           NaN           NaN         NaN
# 10378         0.00          0.11           NaN           NaN         NaN
# 10487         0.00          0.10           NaN           NaN         NaN
# 11093         0.01          0.09           NaN           NaN         NaN
# 11546         0.00          0.08           NaN           NaN         NaN
# 12525         0.00          0.06           NaN           NaN         NaN
# 12569         0.00          0.06           NaN           NaN         NaN
# 13318         0.00          0.05           NaN           NaN         NaN
# 13712         0.00          0.04           NaN           NaN         NaN
# 14128         0.00          0.04           NaN           NaN         NaN
# 14352         0.00          0.03           NaN           NaN         NaN
# 14687         0.00          0.03           NaN           NaN         5.2
# 14772         0.00          0.03           NaN           NaN         NaN
# 15024         0.00          0.02           NaN           NaN         NaN
# 15340         0.00          0.02           NaN           NaN         NaN
# 15417         0.00          0.02           NaN           NaN         NaN
# 15442         0.00          0.02           NaN           NaN         NaN
# 15680         0.00          0.02           NaN           NaN         NaN
# 16019         0.00          0.02           NaN           NaN         NaN
# 16280         0.00          0.01          86.0          49.0         8.2
# 16296         0.00          0.01           NaN           NaN         NaN
# 16306         0.00          0.01           NaN           NaN         NaN
# 16332         0.00          0.01           NaN           NaN         NaN
# 16339         0.00          0.01           NaN           NaN         NaN
# 16662         0.00          0.01           NaN           NaN         NaN
#
#        User_Count                                 Developer Rating
# 475           NaN                                       NaN    NaN
# 1301          NaN                                       NaN    NaN
# 1667          NaN                                       NaN    NaN
# 2212          NaN                                       NaN    NaN
# 3148          NaN                                       NaN    NaN
# 3159          NaN                                       NaN    NaN
# 3755          NaN                                       NaN    NaN
# 4127        176.0                                Sonic Team   E10+
# 4508          NaN                                       NaN    NaN
# 4615          NaN                                       NaN    NaN
# 5294          NaN                                       NaN    NaN
# 5633          NaN                                       NaN    NaN
# 6256          NaN                                       NaN    NaN
# 6415          NaN                                       NaN    NaN
# 6532          NaN                                       NaN    NaN
# 6626          NaN                                       NaN    NaN
# 6831          NaN                                       NaN    NaN
# 7189          NaN                                       NaN    NaN
# 7333         18.0                           Digital Fiction      T
# 7477          NaN                                       NaN    NaN
# 7930          NaN                                       NaN    NaN
# 8317          NaN                                       NaN    NaN
# 8328          NaN                                       NaN    NaN
# 8358          NaN                                       NaN    NaN
# 8494        350.0                           FireFly Studios      T
# 8754          NaN                                       NaN    NaN
# 8837          NaN                                       NaN    NaN
# 8883          NaN                                       NaN    NaN
# 9511         23.0                           Giants Software      E
# 9739          NaN                                       NaN    NaN
# 10378         NaN                                       NaN    NaN
# 10487         NaN                                       NaN    NaN
# 11093         NaN                                       NaN    NaN
# 11546         NaN                                       NaN    NaN
# 12525         NaN                                       NaN    NaN
# 12569         NaN                                       NaN    NaN
# 13318         NaN                                       NaN    NaN
# 13712         NaN                                       NaN    NaN
# 14128         NaN                                       NaN    NaN
# 14352         NaN                                       NaN    NaN
# 14687         9.0                    Microsoft Game Studios    NaN
# 14772         NaN                                       NaN    NaN
# 15024         NaN                                       NaN    NaN
# 15340         NaN                                       NaN    NaN
# 15417         NaN                                       NaN    NaN
# 15442         NaN                           Giants Software    NaN
# 15680         NaN                                       NaN    NaN
# 16019         NaN  CyberPlanet Interactive Public Co., Ltd.      E
# 16280       324.0                          Gearbox Software   E10+
# 16296         NaN                                       NaN    NaN
# 16306         NaN                                       NaN    NaN
# 16332         NaN                          Gearbox Software      M
# 16339         NaN                                       NaN    NaN
# 16662         NaN                                       NaN    NaN

# %%
data.drop(data[data['Publisher'].isnull()].index, inplace=True)
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16665 rows x 16 columns]

# %% [markdown]
# platform sales

# %%
graph1 = sns.catplot(x = 'Platform', data = data, kind = 'count', height = 9, aspect = 1.5)
plt.show(graph1)

# %% [markdown]
# year wise global sales

# %%
graph2 = sns.catplot(x = 'Year_of_Release', data = data, kind = 'count', height = 10, aspect = 3)
plt.show(graph2)

# %% [markdown]
# category wise sales

# %%
graph3 = sns.catplot(x = 'Genre', data = data, kind = 'count', height = 9, aspect = 1.5)
plt.show(graph3)

# %% [markdown]
# year wise platform sales

# %%
ord=['Wii','NES','GB','DS','X360','PS3','PS2','SNES','GBA','PS4','3DS','N64','PS','XB','PC','2600','PSP','XOne','WiiU','GC','GEN','DC','PSV','SAT','SCD','WS','NG','TG16','3DO','GG','PCFX']
graph4=sns.catplot(x='Platform', data=data, kind='count',hue='Year_of_Release', height=10, aspect=2, order=ord)
plt.show(graph4)

# %% [markdown]
# regression

# %%
sns.pairplot(data = data,kind='reg', vars=['NA_Sales','EU_Sales','JP_Sales','Global_Sales','Other_Sales'])

# %% [markdown]
# reading csv file

# %%
df2 = pd.read_csv("videogames.csv")
df2

# %% [markdown]
# null values

# %%
df2.isna().sum()

# %% [markdown]
# replacing null values with 0

# %%
df2.replace(np.nan, 0, inplace=True)
df2 = df2.dropna()
df2.isna().sum()

# %% [markdown]
# dropping columns

# %%
df2.drop(columns=['Critic_Score','Critic_Count','User_Score','User_Count','Developer','Rating'], inplace=True, axis=1)

# %%
print("rows after removing missing values", df2.shape[0])

# %%
df2['Year_of_Release'] = df2['Year_of_Release'].astype(int)

# %% [markdown]
# boxplot

# %%
price_cols = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
df2[price_cols].boxplot(figsize=(24, 8))

# %% [markdown]
# Removing outliers

# %%
def std_based(col_name,df):
    mean = df[col_name].mean()
    std = df[col_name].std()
    cut_off = std * 2
    lower, upper = mean - cut_off, mean + cut_off
    new_df = df[(df[col_name] < upper) & (df[col_name] > lower)]
    return new_df

# %%
print(f"dataset size before removing outliers= {df2.shape[0]}")
for col in price_cols:
    df2 = std_based(col, df2)
print(f"dataset size after removing outliers= {df2.shape[0]}")

# %%
labeled_df = pd.get_dummies(
    df2,
    columns=["Platform", "Genre", 'Publisher'], 
    prefix=["platform", "genre", 'pub']
)
labeled_df.head()

# %%
labeled_df.shape

# %%
labeled_df.dtypes

# %% [markdown]
# dropping duplicates

# %%
bins = pd.qcut(labeled_df['NA_Sales'],7, duplicates='drop')
bins.value_counts(sort=False)

# %%
bins = pd.qcut(labeled_df['EU_Sales'],7, duplicates='drop')
bins.value_counts(sort=False)

# %%
bins = pd.qcut(labeled_df['JP_Sales'],7, duplicates='drop')
bins.value_counts(sort=False)

# %%
bins = pd.qcut(labeled_df['Other_Sales'],7, duplicates='drop')
bins.value_counts(sort=False)

# %%
bins = pd.qcut(labeled_df['Global_Sales'],7, duplicates='drop')
bins.value_counts(sort=False)

# %%
def sales_category(value):
    if value > 0.31:
        return 5
    elif value > 0.16:
        return 4
    elif value > 0.09:
        return 3
    elif value > 0.04:
        return 2
    else :
        return 1

# %%
labeled_df[price_cols] = labeled_df[price_cols].applymap(sales_category)
labeled_df = labeled_df.sample(frac=0.2, random_state=1)

# %%
from sklearn.model_selection import train_test_split
y_na = labeled_df['NA_Sales']
y_eu = labeled_df['EU_Sales']
y_jp = labeled_df['JP_Sales']
y_other = labeled_df['Other_Sales']
y_global = labeled_df['Global_Sales']
x = labeled_df.drop(columns=[*price_cols, 'Global_Sales', 'Name'])

# %%
x_train_na, x_test_na, y_train_na, y_test_na = train_test_split(x, y_na, test_size=0.2, random_state=1)
x_train_eu, x_test_eu, y_train_eu, y_test_eu = train_test_split(x, y_eu, test_size=0.2, random_state=1)
x_train_jp, x_test_jp, y_train_jp, y_test_jp = train_test_split(x, y_jp, test_size=0.2, random_state=1)
x_train_global, x_test_global, y_train_global, y_test_global = train_test_split(x, y_global, test_size=0.2, random_state=1)
x_train_other, x_test_other, y_train_other, y_test_other = train_test_split(x, y_other, test_size=0.2, random_state=1)

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = SVC()

scores_na = cross_val_score(clf, x, y_na, cv=10)
print("CV scores of NA = {}".format(scores_na))
print("mean CV score of NA= {}".format(scores_na.mean()))

scores_eu = cross_val_score(clf, x, y_eu, cv=10)
print("CV scores of EU = {}".format(scores_eu))
print("mean CV score of EU = {}".format(scores_eu.mean()))

scores_jp = cross_val_score(clf, x, y_jp, cv=10)
print("CV scores of JP = {}".format(scores_jp))
print("mean CV score of JP = {}".format(scores_jp.mean()))

scores_other = cross_val_score(clf, x, y_other, cv=10)
print("CV scores of Other = {}".format(scores_other))
print("mean CV score of Other = {}".format(scores_other.mean()))

scores_global = cross_val_score(clf, x, y_other, cv=10)
print("CV scores of Global = {}".format(scores_global))
print("mean CV score of Global = {}".format(scores_global.mean()))

# %%
params = {'C': [0.1, 1.0, 10.0],'kernel': ['linear', 'rbf',]}
svc_grid_na = GridSearchCV(clf, param_grid = params, scoring='accuracy', n_jobs=-1, cv=10)
svc_grid_eu = GridSearchCV(clf, param_grid = params, scoring='accuracy', n_jobs=-1, cv=10)
svc_grid_jp = GridSearchCV(clf, param_grid = params, scoring='accuracy', n_jobs=-1, cv=10)
svc_grid_other = GridSearchCV(clf, param_grid = params, scoring='accuracy', n_jobs=-1, cv=10)
svc_grid_global = GridSearchCV(clf, param_grid = params, scoring='accuracy', n_jobs=-1, cv=10)

# %% [markdown]
# FINAL SCORE (of diffrent regions)

# %%
svc_grid_na.fit(x_train_na, y_train_na)
print(svc_grid_na.score(x_test_na, y_test_na))
print(svc_grid_na.best_params_)

# %%
svc_grid_eu.fit(x_train_eu, y_train_eu)
print(svc_grid_eu.score(x_test_eu, y_test_eu))
print(svc_grid_eu.best_params_)

# %%
svc_grid_jp.fit(x_train_jp, y_train_jp)
print(svc_grid_jp.score(x_test_jp, y_test_jp))
print(svc_grid_jp.best_params_)

# %%
svc_grid_other.fit(x_train_other, y_train_other)
print(svc_grid_other.score(x_test_other, y_test_other))
print(svc_grid_other.best_params_)

# %%
svc_grid_global.fit(x_train_global, y_train_global)
print(svc_grid_global.score(x_test_global, y_test_global))
print(svc_grid_global.best_params_)
